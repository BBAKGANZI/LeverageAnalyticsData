# %%
# !pip install finance-datareader
# Out:
# Collecting finance-datareader
#   Downloading finance_datareader-0.9.31-py3-none-any.whl (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from finance-datareader) (4.2.6)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.7/dist-packages (from finance-datareader) (1.1.5)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from finance-datareader) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from finance-datareader) (4.62.3)
# Collecting requests-file
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19.2->finance-datareader) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19.2->finance-datareader) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19.2->finance-datareader) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->finance-datareader) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->finance-datareader) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->finance-datareader) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->finance-datareader) (1.24.3)
# Installing collected packages: requests-file, finance-datareader
# Successfully installed finance-datareader-0.9.31 requests-file-1.5.1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os

# %matplotlib inline
warnings.filterwarnings('ignore')

plt.rcParams['font.family'] = 'NanumGothic'

# %%
import FinanceDataReader as fdr

# %%
df = fdr.StockListing('KRX')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6601 entries, 0 to 6600
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Symbol          6601 non-null   object
#  1   Market          6601 non-null   object
#  2   Name            6601 non-null   object
#  3   Sector          2466 non-null   object
#  4   Industry        2447 non-null   object
#  5   ListingDate     2466 non-null   datetime64[ns]
#  6   SettleMonth     2466 non-null   object
#  7   Representative  2466 non-null   object
#  8   HomePage        2318 non-null   object
#  9   Region          2466 non-null   object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 567.3+ KB

# %%
df
# Out:
#       Symbol  Market  ...                       HomePage Region
# 0     060310  KOSDAQ  ...           http://www.3sref.com  서울특별시
# 1     095570   KOSPI  ...         http://www.ajnet.co.kr  서울특별시
# 2     006840   KOSPI  ...  http://www.aekyunggroup.co.kr  서울특별시
# 3     054620  KOSDAQ  ...   http://www.apsholdings.co.kr    경기도
# 4     265520  KOSDAQ  ...     http://www.apsystems.co.kr    경기도
# ...      ...     ...  ...                            ...    ...
# 6596  000547   KOSPI  ...                            NaN    NaN
# 6597  000545   KOSPI  ...                            NaN    NaN
# 6598  003280   KOSPI  ...         http://www.heung-a.com  서울특별시
# 6599  037440  KOSDAQ  ...          http://www.heerim.com  서울특별시
# 6600  238490  KOSDAQ  ...          http://www.hims.co.kr  인천광역시
#
# [6601 rows x 10 columns]

# %%
search='삼성전자'
df[df['Name']=='삼성전자']
# Out:
#       Symbol Market  Name  ... Representative              HomePage Region
# 3502  005930  KOSPI  삼성전자  ...  김기남, 김현석, 고동진  http://www.sec.co.kr    경기도
#
# [1 rows x 10 columns]

# %%
# 1996-11-05~
stock=fdr.DataReader('005930','2021')
stock
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2021-01-04  81000  84400  80200  83000  38655276  0.024691
# 2021-01-05  81600  83900  81600  83900  35335669  0.010843
# 2021-01-06  83300  84500  82100  82200  42089013 -0.020262
# 2021-01-07  82800  84200  82700  82900  32644642  0.008516
# 2021-01-08  83300  90000  83000  88800  59013307  0.071170
# ...           ...    ...    ...    ...       ...       ...
# 2021-10-12  70700  70900  68700  69000  31001484 -0.034965
# 2021-10-13  68700  69600  68300  68800  24172015 -0.002899
# 2021-10-14  69000  69800  68800  69400  19520641  0.008721
# 2021-10-15  70200  71000  70000  70100  18051612  0.010086
# 2021-10-18  70200  70300  69200  70200  11880667  0.001427
#
# [195 rows x 6 columns]

# %%
search='삼성전자'
search=df[df['Name']==search]
display(search)
search_num=int(search['Symbol'])        # int
search_num
# Out:
#       Symbol Market  Name  ... Representative              HomePage Region
# 3502  005930  KOSPI  삼성전자  ...  김기남, 김현석, 고동진  http://www.sec.co.kr    경기도
#
# [1 rows x 10 columns]
# 5930

# %%
stock=fdr.DataReader(search_num)        # error code: isdigit
stock
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-d26f90eb373c> in <module>()
# ----> 1 stock=fdr.DataReader(search_num)
#       2 stock
#
# /usr/local/lib/python3.7/dist-packages/FinanceDataReader/data.py in DataReader(symbol, start, end, exchange, data_source)
#      29
#      30     # KRX and Naver Finance
# ---> 31     if (symbol[:5].isdigit() and exchange==None) or \
#      32        (symbol[:5].isdigit() and exchange and exchange.upper() in ['KRX', '한국거래소']):
#      33         return NaverDailyReader(symbol, start, end, exchange, data_source).read()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'isdigit'

# %%
stock=fdr.DataReader(str(search_num).zfill(6))        
stock
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 1997-09-23   1209   1215   1192   1192     66140       NaN
# 1997-09-24   1186   1213   1165   1194     93880  0.001678
# 1997-09-25   1193   1193   1170   1179     70400 -0.012563
# 1997-09-26   1170   1179   1161   1174     70500 -0.004241
# 1997-09-27   1170   1170   1152   1158     84610 -0.013629
# ...           ...    ...    ...    ...       ...       ...
# 2021-10-12  70700  70900  68700  69000  31001484 -0.034965
# 2021-10-13  68700  69600  68300  68800  24172015 -0.002899
# 2021-10-14  69000  69800  68800  69400  19520641  0.008721
# 2021-10-15  70200  71000  70000  70100  18051612  0.010086
# 2021-10-18  70200  70300  69200  70100  12461422  0.000000
#
# [6000 rows x 6 columns]

# %%
# 시계열자료임으로 요일 연관성 확인 위해
# 연, 월, 일 생성
stock.index
# Out:
# DatetimeIndex(['1997-09-23', '1997-09-24', '1997-09-25', '1997-09-26',
#                '1997-09-27', '1997-09-29', '1997-09-30', '1997-10-01',
#                '1997-10-02', '1997-10-04',
#                ...
#                '2021-10-01', '2021-10-05', '2021-10-06', '2021-10-07',
#                '2021-10-08', '2021-10-12', '2021-10-13', '2021-10-14',
#                '2021-10-15', '2021-10-18'],
#               dtype='datetime64[ns]', name='Date', length=6000, freq=None)

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6000 entries, 1997-09-23 to 2021-10-18
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    6000 non-null   int64
#  1   High    6000 non-null   int64
#  2   Low     6000 non-null   int64
#  3   Close   6000 non-null   int64
#  4   Volume  6000 non-null   int64
#  5   Change  5999 non-null   float64
# dtypes: float64(1), int64(5)
# memory usage: 328.1 KB

# %%
stock['year']=stock.index.year
stock['month']=stock.index.month
stock['day']=stock.index.day
stock
# Out:
#              Open   High    Low  Close    Volume    Change  year  month  day
# Date
# 1997-09-23   1209   1215   1192   1192     66140       NaN  1997      9   23
# 1997-09-24   1186   1213   1165   1194     93880  0.001678  1997      9   24
# 1997-09-25   1193   1193   1170   1179     70400 -0.012563  1997      9   25
# 1997-09-26   1170   1179   1161   1174     70500 -0.004241  1997      9   26
# 1997-09-27   1170   1170   1152   1158     84610 -0.013629  1997      9   27
# ...           ...    ...    ...    ...       ...       ...   ...    ...  ...
# 2021-10-12  70700  70900  68700  69000  31001484 -0.034965  2021     10   12
# 2021-10-13  68700  69600  68300  68800  24172015 -0.002899  2021     10   13
# 2021-10-14  69000  69800  68800  69400  19520641  0.008721  2021     10   14
# 2021-10-15  70200  71000  70000  70100  18051612  0.010086  2021     10   15
# 2021-10-18  70200  70300  69200  70100  12461422  0.000000  2021     10   18
#
# [6000 rows x 9 columns]

# %%
stock.groupby(['year','month']).mean()
# Out:
#                     Open          High  ...    Change        day
# year month                              ...
# 1997 9       1176.000000   1191.000000  ... -0.000488  26.285714
#      10      1027.230769   1045.730769  ... -0.020538  16.576923
#      11       796.280000    817.440000  ...  0.005632  15.400000
#      12       748.590909    778.318182  ... -0.002667  13.318182
# 1998 1       1107.272727   1133.727273  ...  0.040711  15.954545
# ...                  ...           ...  ...       ...        ...
# 2021 6      81195.454545  81590.909091  ...  0.000147  15.318182
#      7      79645.454545  79963.636364  ... -0.001228  16.045455
#      8      77204.761905  77914.285714  ... -0.000968  15.952381
#      9      76526.315789  76884.210526  ... -0.001751  14.842105
#      10     71220.000000  71590.000000  ... -0.005452   9.900000
#
# [290 rows x 7 columns]

# %%
# 시각화
plt.figure(figsize=(16,9))
sns.lineplot(y=stock['Close'], x=stock.index)
# Out:
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.

# %%
# 1990~2000, 2000~2010, 2010~2015, 2015~2020
time_steps = [['1990', '2000'], 
              ['2000', '2010'], 
              ['2010', '2015'], 
              ['2015', '2020']]

fig, axes = plt.subplots(2, 2)
fig.set_size_inches(16, 9)
for i in range(4):
    ax = axes[i//2, i%2]
    df = stock.loc[(stock.index > time_steps[i][0]) & (stock.index < time_steps[i][1])]
    sns.lineplot(y=df['Close'], x=df.index, ax=ax)
    ax.set_title(f'{time_steps[i][0]}~{time_steps[i][1]}')
    ax.set_xlabel('time')
    ax.set_ylabel('price')
plt.tight_layout()
plt.show()
# Out:
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.

# %%
# 데이터의 전처리
# 스케일

from sklearn.preprocessing import MinMaxScaler
cols=['Open','High','Low','Close','Volume']

scaler=MinMaxScaler()
scaled=scaler.fit_transform(stock[cols])
scaled
# Out:
# array([[1.33887043e-02, 1.25516529e-02, 1.33184358e-02, 6.25186726e-03,
#         7.32397298e-04],
#        [1.31339978e-02, 1.25309917e-02, 1.30167598e-02, 6.27399776e-03,
#         1.03957451e-03],
#        [1.32115172e-02, 1.23243802e-02, 1.30726257e-02, 6.10801899e-03,
#         7.79570151e-04],
#        ...,
#        [7.64119601e-01, 7.21074380e-01, 7.68715084e-01, 7.60990561e-01,
#         2.16160640e-01],
#        [7.77408638e-01, 7.33471074e-01, 7.82122905e-01, 7.68736238e-01,
#         1.99893436e-01],
#        [7.77408638e-01, 7.26239669e-01, 7.73184358e-01, 7.68736238e-01,
#         1.37990804e-01]])

# %%
# 스케일 자료를 새로운 데이터 프레임으로 제작
df1 = pd.DataFrame(scaled, columns=cols)
df1
# Out:
#           Open      High       Low     Close    Volume
# 0     0.013389  0.012552  0.013318  0.006252  0.000732
# 1     0.013134  0.012531  0.013017  0.006274  0.001040
# 2     0.013212  0.012324  0.013073  0.006108  0.000780
# 3     0.012957  0.012180  0.012972  0.006053  0.000781
# 4     0.012957  0.012087  0.012872  0.005876  0.000937
# ...        ...       ...       ...       ...       ...
# 5995  0.782946  0.732438  0.767598  0.756564  0.343293
# 5996  0.760797  0.719008  0.763128  0.754351  0.267667
# 5997  0.764120  0.721074  0.768715  0.760991  0.216161
# 5998  0.777409  0.733471  0.782123  0.768736  0.199893
# 5999  0.777409  0.726240  0.773184  0.768736  0.137991
#
# [6000 rows x 5 columns]

# %%
# 데이터 분할
# shuffle을 False로 하면 순서대로 자료 잘림

X=df1.drop(['Close'], 1)
y=df1['Close']

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(X,y, test_size=0.2, random_state=777, shuffle=False)
x_train
# Out:
#           Open      High       Low    Volume
# 0     0.013389  0.012552  0.013318  0.000732
# 1     0.013134  0.012531  0.013017  0.001040
# 2     0.013212  0.012324  0.013073  0.000780
# 3     0.012957  0.012180  0.012972  0.000781
# 4     0.012957  0.012087  0.012872  0.000937
# ...        ...       ...       ...       ...
# 4795  0.346622  0.331808  0.349721  0.001812
# 4796  0.355925  0.339876  0.357542  0.002160
# 4797  0.367885  0.343182  0.363352  0.002806
# 4798  0.365227  0.341322  0.364916  0.001718
# 4799  0.363455  0.341322  0.364916  0.001390
#
# [4800 rows x 4 columns]

# %%
x_test
# Out:
#           Open      High       Low    Volume
# 4800  0.365449  0.347314  0.366480  0.002944
# 4801  0.374308  0.350826  0.372961  0.004004
# 4802  0.371429  0.360950  0.374749  0.006320
# 4803  0.385382  0.362190  0.387263  0.003441
# 4804  0.381838  0.359091  0.381453  0.003400
# ...        ...       ...       ...       ...
# 5995  0.782946  0.732438  0.767598  0.343293
# 5996  0.760797  0.719008  0.763128  0.267667
# 5997  0.764120  0.721074  0.768715  0.216161
# 5998  0.777409  0.733471  0.782123  0.199893
# 5999  0.777409  0.726240  0.773184  0.137991
#
# [1200 rows x 4 columns]

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (4800, 4) (4800,)
# (1200, 4) (1200,)

# %%
# ---------슬라이싱 하면서 자료 일정량 잘라서 갖고옴
import tensorflow as tf
def windowed_dataset(series, window_size, batch_size, shuffle):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    if shuffle:
        ds = ds.shuffle(1000)
    ds = ds.map(lambda w: (w[:-1], w[-1]))
    return ds.batch(batch_size).prefetch(1)

# %%
WINDOW_SIZE=20
BATCH_SIZE=32

# trian_data는 학습용 데이터셋, test_data는 검증용 데이터셋 입니다.
# WINDOW_SIZE와 BATCH_SIZE를 각 데이터셋에 적용해주세요.
train_data = windowed_dataset(y_train, WINDOW_SIZE, BATCH_SIZE, True)
test_data = windowed_dataset(y_test, WINDOW_SIZE, BATCH_SIZE, False)

# %%
# ---------------------------
# X: (batch_size, window_size, feature)
# Y: (batch_size, feature)
for data in train_data.take(1):
    print(f'데이터셋(X) 구성(batch_size, window_size, feature갯수): {data[0].shape}')
    print(f'데이터셋(Y) 구성(batch_size, window_size, feature갯수): {data[1].shape}')
# Out:
# 데이터셋(X) 구성(batch_size, window_size, feature갯수): (32, 20, 1)
# 데이터셋(Y) 구성(batch_size, window_size, feature갯수): (32, 1)

# %%
# --------------------------------------------
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, Lambda
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
model = Sequential([
    # 1차원 feature map 생성합니다. filters는 32로, kernel_size는 5로 지정해주세요.
    Conv1D(filters=32, kernel_size=5,
           padding="causal",
           activation="relu",
           input_shape=[WINDOW_SIZE, 1]),
    # LSTM과 Dense 레이러를 사용해주세요. 활성함수는 각각 tanh와 relu로 지정합니다.
    LSTM(16, activation='relu'),
    Dense(16, activation="relu"),
    Dense(1),
])

# %%
# -------------------------------------------
# Sequence 학습에 비교적 좋은 퍼포먼스를 내는 Huber()를 사용합니다.
loss = Huber()
optimizer = Adam(0.0005)
model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])

# %%
# ------------------------------------------------------
# earlystopping은 10번 epoch통안 val_loss 개선이 없다면 학습을 멈춥니다.
earlystopping = EarlyStopping(monitor='val_loss', patience=10)
# val_loss 기준 체크포인터도 생성합니다.
filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename, 
                             save_weights_only=True, 
                             save_best_only=True, 
                             monitor='val_loss', 
                             verbose=1)

# %%
#------------------------------------------------------------
# callbacks로 앞에서 구현한 earlystopping과 checkpoint를 지정해주세요.
history = model.fit(train_data, 
                    validation_data=(test_data), 
                    epochs=50, 
                    callbacks=[checkpoint, earlystopping])
# Out:
# Epoch 1/50
# 150/150 [==============================] - 4s 17ms/step - loss: 1.5127e-04 - mse: 3.0254e-04 - val_loss: 0.0056 - val_mse: 0.0111
#
# Epoch 00001: val_loss improved from inf to 0.00557, saving model to tmp/ckeckpointer.ckpt
# Epoch 2/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.9968e-05 - mse: 3.9935e-05 - val_loss: 0.0033 - val_mse: 0.0066
#
# Epoch 00002: val_loss improved from 0.00557 to 0.00330, saving model to tmp/ckeckpointer.ckpt
# Epoch 3/50
# 150/150 [==============================] - 2s 14ms/step - loss: 2.1408e-05 - mse: 4.2817e-05 - val_loss: 0.0026 - val_mse: 0.0052
#
# Epoch 00003: val_loss improved from 0.00330 to 0.00260, saving model to tmp/ckeckpointer.ckpt
# Epoch 4/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.8637e-05 - mse: 3.7273e-05 - val_loss: 0.0027 - val_mse: 0.0053
#
# Epoch 00004: val_loss did not improve from 0.00260
# Epoch 5/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.8050e-05 - mse: 3.6099e-05 - val_loss: 0.0017 - val_mse: 0.0034
#
# Epoch 00005: val_loss improved from 0.00260 to 0.00169, saving model to tmp/ckeckpointer.ckpt
# Epoch 6/50
# 150/150 [==============================] - 2s 15ms/step - loss: 1.8930e-05 - mse: 3.7860e-05 - val_loss: 0.0012 - val_mse: 0.0024
#
# Epoch 00006: val_loss improved from 0.00169 to 0.00120, saving model to tmp/ckeckpointer.ckpt
# Epoch 7/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.7813e-05 - mse: 3.5625e-05 - val_loss: 0.0011 - val_mse: 0.0022
#
# Epoch 00007: val_loss improved from 0.00120 to 0.00109, saving model to tmp/ckeckpointer.ckpt
# Epoch 8/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.9086e-05 - mse: 3.8172e-05 - val_loss: 0.0012 - val_mse: 0.0024
#
# Epoch 00008: val_loss did not improve from 0.00109
# Epoch 9/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.7050e-05 - mse: 3.4100e-05 - val_loss: 0.0011 - val_mse: 0.0022
#
# Epoch 00009: val_loss improved from 0.00109 to 0.00108, saving model to tmp/ckeckpointer.ckpt
# Epoch 10/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.6833e-05 - mse: 3.3665e-05 - val_loss: 8.2669e-04 - val_mse: 0.0017
#
# Epoch 00010: val_loss improved from 0.00108 to 0.00083, saving model to tmp/ckeckpointer.ckpt
# Epoch 11/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.7892e-05 - mse: 3.5784e-05 - val_loss: 9.5282e-04 - val_mse: 0.0019
#
# Epoch 00011: val_loss did not improve from 0.00083
# Epoch 12/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.9243e-05 - mse: 3.8486e-05 - val_loss: 0.0012 - val_mse: 0.0024
#
# Epoch 00012: val_loss did not improve from 0.00083
# Epoch 13/50
# 150/150 [==============================] - 2s 15ms/step - loss: 1.7582e-05 - mse: 3.5164e-05 - val_loss: 5.1371e-04 - val_mse: 0.0010
#
# Epoch 00013: val_loss improved from 0.00083 to 0.00051, saving model to tmp/ckeckpointer.ckpt
# Epoch 14/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.5974e-05 - mse: 3.1948e-05 - val_loss: 4.9815e-04 - val_mse: 9.9629e-04
#
# Epoch 00014: val_loss improved from 0.00051 to 0.00050, saving model to tmp/ckeckpointer.ckpt
# Epoch 15/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.6070e-05 - mse: 3.2141e-05 - val_loss: 4.7317e-04 - val_mse: 9.4634e-04
#
# Epoch 00015: val_loss improved from 0.00050 to 0.00047, saving model to tmp/ckeckpointer.ckpt
# Epoch 16/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.6218e-05 - mse: 3.2436e-05 - val_loss: 4.4882e-04 - val_mse: 8.9764e-04
#
# Epoch 00016: val_loss improved from 0.00047 to 0.00045, saving model to tmp/ckeckpointer.ckpt
# Epoch 17/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.5622e-05 - mse: 3.1243e-05 - val_loss: 4.7869e-04 - val_mse: 9.5738e-04
#
# Epoch 00017: val_loss did not improve from 0.00045
# Epoch 18/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.5044e-05 - mse: 3.0089e-05 - val_loss: 4.1761e-04 - val_mse: 8.3522e-04
#
# Epoch 00018: val_loss improved from 0.00045 to 0.00042, saving model to tmp/ckeckpointer.ckpt
# Epoch 19/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.5691e-05 - mse: 3.1382e-05 - val_loss: 3.7770e-04 - val_mse: 7.5540e-04
#
# Epoch 00019: val_loss improved from 0.00042 to 0.00038, saving model to tmp/ckeckpointer.ckpt
# Epoch 20/50
# 150/150 [==============================] - 2s 15ms/step - loss: 1.5521e-05 - mse: 3.1043e-05 - val_loss: 3.5050e-04 - val_mse: 7.0101e-04
#
# Epoch 00020: val_loss improved from 0.00038 to 0.00035, saving model to tmp/ckeckpointer.ckpt
# Epoch 21/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.3888e-05 - mse: 2.7775e-05 - val_loss: 3.5849e-04 - val_mse: 7.1698e-04
#
# Epoch 00021: val_loss did not improve from 0.00035
# Epoch 22/50
# 150/150 [==============================] - 2s 15ms/step - loss: 1.4026e-05 - mse: 2.8052e-05 - val_loss: 3.3429e-04 - val_mse: 6.6858e-04
#
# Epoch 00022: val_loss improved from 0.00035 to 0.00033, saving model to tmp/ckeckpointer.ckpt
# Epoch 23/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.3668e-05 - mse: 2.7336e-05 - val_loss: 3.1927e-04 - val_mse: 6.3853e-04
#
# Epoch 00023: val_loss improved from 0.00033 to 0.00032, saving model to tmp/ckeckpointer.ckpt
# Epoch 24/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.3546e-05 - mse: 2.7092e-05 - val_loss: 3.1043e-04 - val_mse: 6.2085e-04
#
# Epoch 00024: val_loss improved from 0.00032 to 0.00031, saving model to tmp/ckeckpointer.ckpt
# Epoch 25/50
# 150/150 [==============================] - 2s 15ms/step - loss: 1.4114e-05 - mse: 2.8229e-05 - val_loss: 2.8904e-04 - val_mse: 5.7808e-04
#
# Epoch 00025: val_loss improved from 0.00031 to 0.00029, saving model to tmp/ckeckpointer.ckpt
# Epoch 26/50
# 150/150 [==============================] - 2s 15ms/step - loss: 1.3589e-05 - mse: 2.7178e-05 - val_loss: 3.3762e-04 - val_mse: 6.7523e-04
#
# Epoch 00026: val_loss did not improve from 0.00029
# Epoch 27/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.3586e-05 - mse: 2.7171e-05 - val_loss: 3.2960e-04 - val_mse: 6.5920e-04
#
# Epoch 00027: val_loss did not improve from 0.00029
# Epoch 28/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.2718e-05 - mse: 2.5435e-05 - val_loss: 2.9689e-04 - val_mse: 5.9379e-04
#
# Epoch 00028: val_loss did not improve from 0.00029
# Epoch 29/50
# 150/150 [==============================] - 2s 15ms/step - loss: 1.2511e-05 - mse: 2.5021e-05 - val_loss: 3.6421e-04 - val_mse: 7.2841e-04
#
# Epoch 00029: val_loss did not improve from 0.00029
# Epoch 30/50
# 150/150 [==============================] - 2s 15ms/step - loss: 1.3086e-05 - mse: 2.6173e-05 - val_loss: 2.4433e-04 - val_mse: 4.8866e-04
#
# Epoch 00030: val_loss improved from 0.00029 to 0.00024, saving model to tmp/ckeckpointer.ckpt
# Epoch 31/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.2458e-05 - mse: 2.4915e-05 - val_loss: 4.5838e-04 - val_mse: 9.1675e-04
#
# Epoch 00031: val_loss did not improve from 0.00024
# Epoch 32/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.2689e-05 - mse: 2.5378e-05 - val_loss: 3.7345e-04 - val_mse: 7.4690e-04
#
# Epoch 00032: val_loss did not improve from 0.00024
# Epoch 33/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.3000e-05 - mse: 2.6000e-05 - val_loss: 3.5894e-04 - val_mse: 7.1788e-04
#
# Epoch 00033: val_loss did not improve from 0.00024
# Epoch 34/50
# 150/150 [==============================] - 2s 15ms/step - loss: 1.1907e-05 - mse: 2.3814e-05 - val_loss: 2.9601e-04 - val_mse: 5.9201e-04
#
# Epoch 00034: val_loss did not improve from 0.00024
# Epoch 35/50
# 150/150 [==============================] - 2s 15ms/step - loss: 1.1273e-05 - mse: 2.2547e-05 - val_loss: 3.2245e-04 - val_mse: 6.4489e-04
#
# Epoch 00035: val_loss did not improve from 0.00024
# Epoch 36/50
# 150/150 [==============================] - 2s 15ms/step - loss: 1.1394e-05 - mse: 2.2789e-05 - val_loss: 4.4183e-04 - val_mse: 8.8366e-04
#
# Epoch 00036: val_loss did not improve from 0.00024
# Epoch 37/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.1101e-05 - mse: 2.2202e-05 - val_loss: 3.5970e-04 - val_mse: 7.1940e-04
#
# Epoch 00037: val_loss did not improve from 0.00024
# Epoch 38/50
# 150/150 [==============================] - 2s 15ms/step - loss: 1.0549e-05 - mse: 2.1099e-05 - val_loss: 3.1112e-04 - val_mse: 6.2224e-04
#
# Epoch 00038: val_loss did not improve from 0.00024
# Epoch 39/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.0832e-05 - mse: 2.1665e-05 - val_loss: 3.4621e-04 - val_mse: 6.9241e-04
#
# Epoch 00039: val_loss did not improve from 0.00024
# Epoch 40/50
# 150/150 [==============================] - 2s 14ms/step - loss: 1.1017e-05 - mse: 2.2034e-05 - val_loss: 6.1510e-04 - val_mse: 0.0012
#
# Epoch 00040: val_loss did not improve from 0.00024

# %%
#-----------------------------------------------------------------
pred = model.predict(test_data)
pred.shape
# Out:
# (1180, 1)

# %%
#------------------------------------------------------------------
# 20일치의 데이터로 21일치를 예측하므로 test_data 사용시 이전 20일은 예측하지 않습니다.
# 따라서 y_test 데이터에 [20:]로 슬라이싱해주세요.
plt.figure(figsize=(12, 9))
plt.plot(np.asarray(y_test)[20:], label='actual')
plt.plot(pred, label='prediction')
plt.legend()
plt.show()
